# %% [markdown]
# # Exercise 5 - Linear Programming
#
#
# Suppose you are managing a production line that assembles two types of robots, Robot A and Robot B.\
# You want to maximize daily profit from production, but you’re constrained by limied resources.\
# Each robot type requires time in two stages: Assembly and Testing. Here are the details:
#
# **Profit per robot**:
#
# - Robot A: \$80
# - Robot B: \$50
#
# **At least 4 robots to be produced per day**
#
# **Time required (in hours)**:
#
# - Assembly: Robot A needs 3 hours, Robot B needs 2 hours
# - Testing: Robot A needs 2 hours, Robot B needs 1 hour
#
# **Daily time available**:
#
# - Assembly: 18 hours
# - Testing: 10 hours
#
# **Objective**:
#
# Maximize the daily profit from producing Robots A and B within the available time constraints.
#
#
# > "Control + Enter" to execute the selected code cell.

# %% [markdown]
# ## Task1: Visualize the feasible polygon
#
# Comlete in the Inequality Form formula you wrote for the first problem, and visualize the Feasible Region along with its corner points.

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# Create grid of x1, x2
x1, x2 = np.meshgrid(np.linspace(0, 10, 500), np.linspace(0, 10, 500))

# Task1.1: Complete Inequalities
min_prod_inequality = 
assembly_inequality = 
testing_inequality  = 
feasible = assembly_inequality & testing_inequality & min_prod_inequality

plt.figure(figsize=(8, 6))

# Fill feasible region
plt.contourf(x1, x2, feasible, levels=[0.5, 1], colors=['lightblue'], alpha=0.7)

# Task1.2: Plot Constraint Lines
# example: 
# c_x1 = np.linspace(0, 10, 500)
# c_x2 = 10 - c_x1
# plt.plot(c_x1, c_x2, label="x1 + x2 <= 10")

# Plot axes limits
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.xlabel("x₁ = Number of Robot A")
plt.ylabel("x₂ = Number of Robot B")
plt.title("Feasible Region and Optimal Solution for Robot Production LP")
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# ### Task1 Solution:

# %%
# The solution will be provided next week.

import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# Create grid of x1, x2
x1, x2 = np.meshgrid(np.linspace(0, 10, 500), np.linspace(0, 10, 500))

# Task1.1: Complete Inequalities
assembly_inequality = 3*x1 + 2*x2 <= 18
testing_inequality  = 2*x1 + x2 <= 10
min_prod_inequality = x1 + x2 >= 4
feasible = assembly_inequality & testing_inequality & min_prod_inequality

plt.figure(figsize=(8, 6))

# Fill feasible region
plt.contourf(x1, x2, feasible, levels=[0.5, 1], colors=['lightblue'], alpha=0.7)

# Task1.2: Plot Constraint Lines
c_x1 = np.linspace(0, 10, 500)
c_x2 = (18 - 3 * c_x1) / 2
plt.plot(c_x1, c_x2, label="3x₁ + 2x₂ = 18")

c_x2 = 10 - 2 * c_x1
plt.plot(c_x1, c_x2, label="2x₁ + x₂ = 10")

c_x2 = 4 - c_x1
plt.plot(c_x1, c_x2, label="x₁ + x₂ = 4")

# Plot axes limits
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.xlabel("x₁ = Number of Robot A")
plt.ylabel("x₂ = Number of Robot B")
plt.title("Feasible Region and Optimal Solution for Robot Production LP")
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# ## Task2: Calulate the solution with simplex solver
#
# Fill in the Matrix Form formulation you wrote in the first execerise, calculate the optimal solution and the maximum profit.

# %%
import numpy as np
from scipy.optimize import linprog

# scipy convert linear programming problems into minimization problems,
# Here we pass negative coefficients for the objective function to transform into a maximization problem.
def simplex(c, A_ub, b_ub):
    c = -np.array(c)
    res = linprog(c, A_ub=A_ub, b_ub=b_ub, method='simplex')
    solution = res.x
    max_objective = -res.fun
    return solution, max_objective


# Task: Complete matrix
matrix_c = 
matrix_G = 
matrix_g =

optimal_solution, max_profit = simplex(matrix_c, matrix_G, matrix_g)
print(f"Optimal x: {optimal_solution}")
print(f"Maximum Profit: {max_profit}")

# %% [markdown]
# ### Task2 Solution:

# %%
import numpy as np
from scipy.optimize import linprog

# scipy convert linear programming problems into minimization problems,
# Here we pass negative coefficients for the objective function to transform into a maximization problem.
def simplex(c, A_ub, b_ub):
    c = -np.array(c)
    res = linprog(c, A_ub=A_ub, b_ub=b_ub, method='simplex')
    solution = res.x
    max_objective = -res.fun
    return solution, max_objective


# Task: Complete matrix
matrix_c = [80, 50]
matrix_G = [
    [3, 2],
    [2, 1],
    [-1, -1],
    [-1, 0],
    [0, -1],
]
matrix_g = [
    18,
    10,
    -4,
    0,
    0,
]

optimal_solution, max_profit = simplex(matrix_c, matrix_G, matrix_g)
print(f"Optimal x: {optimal_solution}")
print(f"Maximum Profit: {max_profit}")
# Out:
# Optimal x: [2. 6.]
# Maximum Profit: 460.0

# %% [markdown]
# ## Further Exercise: Implement a Simplex Solver
#
# The exercise above used the Simplex solver implemented in [scipy](https://docs.scipy.org/doc/scipy/index.html).
#
# If you're interested, you can try implementing the Simplex algorithm yourself.
#
# ### References:
#
# - https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.linprog.html
# - https://github.com/scipy/scipy/blob/main/scipy/optimize/_linprog_simplex.py

# %%
def my_simplex(c, A_ub, b_ub):
    
    # Your solution
    
    return solution, max_value

# %% [markdown]
# Verify your solver

# %%
optimal_solution, max_profit = my_simplex(matrix_c, matrix_G, matrix_g)

print(f"Optimal x: {optimal_solution}")
print(f"Maximum Profit: {max_profit}")
